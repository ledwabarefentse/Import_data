# %% [markdown]
# <a href="https://colab.research.google.com/github/ledwabarefentse/Import_data/blob/main/ImportData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploades = files.upload()
# Out:
#      <input type="file" id="files-f84ce670-7c4e-4b7a-8e57-fa851d39905b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f84ce670-7c4e-4b7a-8e57-fa851d39905b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
global df
df0 = create_dataframe('netflix_titles.csv')
df0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/Attrition_RCA.csv", encoding = "latin-1")
df
# Out:
#         ï»¿Unique_Customer_Key  Start_Period  End_Period  Current_Balance  \
# 0                            1        202102      202202         184865.0
# 1                            2        202102      202202        1276768.0
# 2                            3        202102      202202         107947.0
# 3                            4        202102      202202             51.0
# 4                            5        202102      202202         241753.0
# ...                        ...           ...         ...              ...
# 149995                  149996        202102      202202            980.0
# 149996                  149997        202102      202202           6990.0
# 149997                  149998        202102      202202          11189.0
# 149998                  149999        202102      202202              NaN
# 149999                  150000        202102      202202           2900.0
#
#         Instalment_Amount  Open_Balance  Overdue_Amount        Sub_Segment  \
# ...

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Datasets/Employer_RCA.csv", encoding = "latin-1")
df2.head()
# Out:
#    ï»¿Unique_Customer_Key  Period  SALARY_IND  PENSION_IND  \
# 0                       1  202204           1            0
# 1                       2  202204           1            0
# 2                       3  202204           1            0
# 3                       4  202204           1            0
# 4                       5  202204           1            0
#
#            RAW_EMPLOYER_NAME  CLEANED_EMPLOYER_NAME  \
# 0  adcorp wokforce solutions                    NaN
# 1  adcorp wokforce solutions                    NaN
# 2  adcorp wokforce solutions                    NaN
# 3  adcorp wokforce solutions                    NaN
# 4  adcorp wokforce solutions                    NaN
#
#              INDUSTRY_CATEGORY  \
# 0  BUSINESS AND ADMINISTRATIVE
# 1  BUSINESS AND ADMINISTRATIVE
# 2  BUSINESS AND ADMINISTRATIVE
# 3  BUSINESS AND ADMINISTRATIVE
# 4  BUSINESS AND ADMINISTRATIVE
#
#                             INDUSTRY_SUB_CATEGORY INDUSTRY_OUTLOOK  \
# ...
